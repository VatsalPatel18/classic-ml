# %%
# !pip install lifelines
# Out:
# Collecting lifelines
#   Downloading lifelines-0.29.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy<2.0,>=1.14.0 in /home/vpp1/anaconda3/lib/python3.11/site-packages (from lifelines) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in /home/vpp1/anaconda3/lib/python3.11/site-packages (from lifelines) (1.11.4)
# Requirement already satisfied: pandas>=2.1 in /home/vpp1/anaconda3/lib/python3.11/site-packages (from lifelines) (2.1.4)
# Requirement already satisfied: matplotlib>=3.0 in /home/vpp1/anaconda3/lib/python3.11/site-packages (from lifelines) (3.8.0)
# Collecting autograd>=1.5 (from lifelines)
#   Downloading autograd-1.7.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting autograd-gamma>=0.3 (from lifelines)
#   Using cached autograd-gamma-0.5.0.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting formulaic>=0.2.2 (from lifelines)
#   Downloading formulaic-1.0.2-py3-none-any.whl.metadata (6.8 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=0.2.2->lifelines)
#   Using cached interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/vpp1/anaconda3/lib/python3.11/site-packages (from formulaic>=0.2.2->lifelines) (4.9.0)
# Requirement already satisfied: wrapt>=1.0 in /home/vpp1/anaconda3/lib/python3.11/site-packages (from formulaic>=0.2.2->lifelines) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vpp1/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0->lifelines) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/vpp1/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0->lifelines) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vpp1/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0->lifelines) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/vpp1/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0->lifelines) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/vpp1/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0->lifelines) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/vpp1/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0->lifelines) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/vpp1/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0->lifelines) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/vpp1/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0->lifelines) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/vpp1/anaconda3/lib/python3.11/site-packages (from pandas>=2.1->lifelines) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/vpp1/anaconda3/lib/python3.11/site-packages (from pandas>=2.1->lifelines) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/vpp1/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->lifelines) (1.16.0)
# Downloading lifelines-0.29.0-py3-none-any.whl (349 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.3/349.3 kB 869.4 kB/s eta 0:00:00 eta 0:00:010:0101
# Downloading autograd-1.7.0-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 439.7 kB/s eta 0:00:001m91.3 MB/s eta 0:00:01
# Downloading formulaic-1.0.2-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.5/94.5 kB 644.3 kB/s eta 0:00:001m2.4 MB/s eta 0:00:01m
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Building wheels for collected packages: autograd-gamma
#   Building wheel for autograd-gamma (setup.py) ... done
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4031 sha256=f9f8caf71086aab3806f1602869086ca6b95569fc48433dabc0a85822b02758a
#   Stored in directory: /home/vpp1/.cache/pip/wheels/8b/67/f4/2caaae2146198dcb824f31a303833b07b14a5ec863fb3acd7b
# Successfully built autograd-gamma
# Installing collected packages: interface-meta, autograd, autograd-gamma, formulaic, lifelines
# Successfully installed autograd-1.7.0 autograd-gamma-0.5.0 formulaic-1.0.2 interface-meta-1.3.0 lifelines-0.29.0
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
pdf = pd.read_csv()

# %%
import pandas as pd
import numpy as np

# Generating a dataframe with PatientID as the index and 10 random feature columns
np.random.seed(42)
patient_ids = [f"Patient_{i}" for i in range(1, 51)]
features = np.random.rand(50, 10)  # 50 patients, 10 features

# Create a DataFrame with PatientID as a column and the generated features
df_features = pd.DataFrame(features, columns=[f"Feature_{i}" for i in range(1, 11)])
df_features.insert(0, "PatientID", patient_ids)

# Generating a clinical dataframe for the same PatientIDs with "Overall Survival (Months)" and "Overall Survival Status"
survival_months = np.random.randint(1, 120, size=50)  # Survival months between 1 and 120
survival_status = np.random.randint(0, 2, size=50)    # 0 = Alive, 1 = Deceased

df_clinical = pd.DataFrame({
    "PatientID": patient_ids,
    "Overall Survival (Months)": survival_months,
    "Overall Survival Status": survival_status
})

# Save these dataframes to CSV files for testing
df_features.to_csv('./test_features.csv', index=False)
df_clinical.to_csv('./test_clinical.csv', index=False)

# %%
# df_clinical

# %%
xdf = pd.read_csv('./test_clinical.csv')

# %%
xdf
# Out:
#      PatientID  Overall Survival (Months)  Overall Survival Status
# 0    Patient_1                        118                        0
# 1    Patient_2                         63                        1
# 2    Patient_3                         17                        0
# 3    Patient_4                         73                        1
# 4    Patient_5                         33                        1
# 5    Patient_6                        117                        0
# 6    Patient_7                         84                        0
# 7    Patient_8                         77                        0
# 8    Patient_9                         92                        0
# 9   Patient_10                        112                        1
# 10  Patient_11                         29                        0
# 11  Patient_12                         13                        0
# 12  Patient_13                         46                        0
# 13  Patient_14                         35                        0
# 14  Patient_15                          6                        0
# 15  Patient_16                         82                        0
# 16  Patient_17                        115                        1
# 17  Patient_18                         69                        1
# 18  Patient_19                         47                        0
# 19  Patient_20                         25                        0
# 20  Patient_21                         66                        0
# 21  Patient_22                         10                        1
# 22  Patient_23                         56                        0
# 23  Patient_24                         30                        1
# 24  Patient_25                        114                        0
# 25  Patient_26                        109                        0
# 26  Patient_27                          5                        0
# 27  Patient_28                        119                        0
# 28  Patient_29                         33                        1
# 29  Patient_30                        118                        1
# 30  Patient_31                         65                        0
# 31  Patient_32                         18                        0
# 32  Patient_33                         96                        1
# 33  Patient_34                        111                        1
# 34  Patient_35                         49                        1
# 35  Patient_36                         11                        1
# 36  Patient_37                         85                        0
# 37  Patient_38                         26                        1
# 38  Patient_39                         63                        0
# 39  Patient_40                         89                        1
# 40  Patient_41                         86                        1
# 41  Patient_42                         59                        1
# 42  Patient_43                         27                        1
# 43  Patient_44                         49                        1
# 44  Patient_45                         77                        0
# 45  Patient_46                         33                        0
# 46  Patient_47                         98                        1
# 47  Patient_48                        105                        1
# 48  Patient_49                         99                        0
# 49  Patient_50                          1                        1

# %%
# Paths to your test CSV files
data_path = './test_features.csv'  # The feature CSV you created
clinical_df_path = './test_clinical.csv'  # The clinical CSV

# Initialize the class instance
clustering_survival = ClusteringSurvival(data_path=data_path, clinical_df_path=clinical_df_path,)

# %%
# Perform PCA and t-SNE
clustering_survival.pca_tsne()

# %%
# Find optimal clusters
clustering_survival.find_optimal_clusters()
# Out:
# /home/vpp1/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/vpp1/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/vpp1/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/vpp1/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/vpp1/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/vpp1/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/vpp1/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/vpp1/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/vpp1/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
clustering_survival.df
# Out:
#             Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# PatientID
# Patient_1    0.374540   0.950714   0.731994   0.598658   0.156019   0.155995
# Patient_2    0.020584   0.969910   0.832443   0.212339   0.181825   0.183405
# Patient_3    0.611853   0.139494   0.292145   0.366362   0.456070   0.785176
# Patient_4    0.607545   0.170524   0.065052   0.948886   0.965632   0.808397
# Patient_5    0.122038   0.495177   0.034389   0.909320   0.258780   0.662522
# Patient_6    0.969585   0.775133   0.939499   0.894827   0.597900   0.921874
# Patient_7    0.388677   0.271349   0.828738   0.356753   0.280935   0.542696
# Patient_8    0.772245   0.198716   0.005522   0.815461   0.706857   0.729007
# Patient_9    0.863103   0.623298   0.330898   0.063558   0.310982   0.325183
# Patient_10   0.119594   0.713245   0.760785   0.561277   0.770967   0.493796
# Patient_11   0.031429   0.636410   0.314356   0.508571   0.907566   0.249292
# Patient_12   0.289751   0.161221   0.929698   0.808120   0.633404   0.871461
# Patient_13   0.807440   0.896091   0.318003   0.110052   0.227935   0.427108
# Patient_14   0.417411   0.222108   0.119865   0.337615   0.942910   0.323203
# Patient_15   0.962447   0.251782   0.497249   0.300878   0.284840   0.036887
# Patient_16   0.908266   0.239562   0.144895   0.489453   0.985650   0.242055
# Patient_17   0.367783   0.632306   0.633530   0.535775   0.090290   0.835302
# Patient_18   0.677564   0.016588   0.512093   0.226496   0.645173   0.174366
# Patient_19   0.341066   0.113474   0.924694   0.877339   0.257942   0.659984
# Patient_20   0.093103   0.897216   0.900418   0.633101   0.339030   0.349210
# Patient_21   0.642032   0.084140   0.161629   0.898554   0.606429   0.009197
# Patient_22   0.548734   0.691895   0.651961   0.224269   0.712179   0.237249
# Patient_23   0.657613   0.568309   0.093675   0.367716   0.265202   0.243990
# Patient_24   0.794811   0.502637   0.576904   0.492518   0.195243   0.722452
# Patient_25   0.940459   0.953929   0.914864   0.370159   0.015457   0.928319
# Patient_26   0.294449   0.385098   0.851137   0.316922   0.169493   0.556801
# Patient_27   0.615007   0.990054   0.140084   0.518330   0.877373   0.740769
# Patient_28   0.809361   0.810113   0.867072   0.913241   0.511342   0.501516
# Patient_29   0.890005   0.337995   0.375583   0.093982   0.578280   0.035942
# Patient_30   0.030500   0.037348   0.822601   0.360191   0.127061   0.522243
# Patient_31   0.051682   0.531355   0.540635   0.637430   0.726091   0.975852
# Patient_32   0.438971   0.078456   0.025351   0.962648   0.835980   0.695974
# Patient_33   0.549227   0.714596   0.660197   0.279934   0.954865   0.737897
# Patient_34   0.355973   0.757846   0.014393   0.116073   0.046003   0.040729
# Patient_35   0.491616   0.473472   0.173202   0.433852   0.398505   0.615850
# Patient_36   0.503136   0.856490   0.658694   0.162934   0.070569   0.642419
# Patient_37   0.388170   0.643288   0.458253   0.545617   0.941465   0.386103
# Patient_38   0.100778   0.018222   0.094443   0.683007   0.071189   0.318976
# Patient_39   0.118165   0.696737   0.628943   0.877472   0.735071   0.803481
# Patient_40   0.990505   0.412618   0.372018   0.776413   0.340804   0.930757
# Patient_41   0.103124   0.902553   0.505252   0.826457   0.320050   0.895523
# Patient_42   0.319314   0.950062   0.950607   0.573438   0.631837   0.448446
# Patient_43   0.791579   0.789618   0.091206   0.494420   0.057559   0.549529
# Patient_44   0.142992   0.761511   0.618218   0.101123   0.084107   0.700969
# Patient_45   0.084838   0.986640   0.374271   0.370642   0.812800   0.947249
# Patient_46   0.777147   0.558404   0.424222   0.906354   0.111197   0.492625
# Patient_47   0.117526   0.649210   0.746045   0.583369   0.962173   0.374871
# Patient_48   0.012154   0.969879   0.043160   0.891143   0.527701   0.992965
# Patient_49   0.629399   0.695749   0.454541   0.627558   0.584314   0.901158
# Patient_50   0.455657   0.620133   0.277381   0.188121   0.463698   0.353352
#
#             Feature_7  Feature_8  Feature_9  Feature_10  \
# PatientID
# Patient_1    0.058084   0.866176   0.601115    0.708073
# Patient_2    0.304242   0.524756   0.431945    0.291229
# Patient_3    0.199674   0.514234   0.592415    0.046450
# Patient_4    0.304614   0.097672   0.684233    0.440152
# Patient_5    0.311711   0.520068   0.546710    0.184854
# Patient_6    0.088493   0.195983   0.045227    0.325330
# Patient_7    0.140924   0.802197   0.074551    0.986887
# Patient_8    0.771270   0.074045   0.358466    0.115869
# Patient_9    0.729606   0.637557   0.887213    0.472215
# Patient_10   0.522733   0.427541   0.025419    0.107891
# Patient_11   0.410383   0.755551   0.228798    0.076980
# Patient_12   0.803672   0.186570   0.892559    0.539342
# Patient_13   0.818015   0.860731   0.006952    0.510747
# Patient_14   0.518791   0.703019   0.363630    0.971782
# Patient_15   0.609564   0.502679   0.051479    0.278646
# Patient_16   0.672136   0.761620   0.237638    0.728216
# Patient_17   0.320780   0.186519   0.040775    0.590893
# Patient_18   0.690938   0.386735   0.936730    0.137521
# Patient_19   0.817222   0.555201   0.529651    0.241852
# Patient_20   0.725956   0.897110   0.887086    0.779876
# Patient_21   0.101472   0.663502   0.005062    0.160808
# Patient_22   0.325400   0.746491   0.649633    0.849223
# Patient_23   0.973011   0.393098   0.892047    0.631139
# Patient_24   0.280772   0.024316   0.645472    0.177111
# Patient_25   0.428184   0.966655   0.963620    0.853009
# Patient_26   0.936155   0.696030   0.570061    0.097176
# Patient_27   0.697016   0.702484   0.359491    0.293592
# Patient_28   0.798295   0.649964   0.701967    0.795793
# Patient_29   0.465598   0.542645   0.286541    0.590833
# Patient_30   0.769994   0.215821   0.622890    0.085347
# Patient_31   0.516300   0.322956   0.795186    0.270832
# Patient_32   0.408953   0.173294   0.156437    0.250243
# Patient_33   0.554354   0.611721   0.419600    0.247731
# Patient_34   0.855461   0.703658   0.474174    0.097834
# Patient_35   0.635094   0.045304   0.374613    0.625860
# Patient_36   0.026511   0.585776   0.940230    0.575474
# Patient_37   0.961191   0.905351   0.195791    0.069361
# Patient_38   0.844875   0.023272   0.814468    0.281855
# Patient_39   0.282035   0.177440   0.750615    0.806835
# Patient_40   0.858413   0.428994   0.750871    0.754543
# Patient_41   0.389202   0.010838   0.905382    0.091287
# Patient_42   0.293211   0.328665   0.672518    0.752375
# Patient_43   0.441531   0.887704   0.350915    0.117067
# Patient_44   0.072763   0.821860   0.706242    0.081349
# Patient_45   0.986001   0.753378   0.376260    0.083501
# Patient_46   0.011354   0.468661   0.056303    0.118818
# Patient_47   0.285712   0.868599   0.223596    0.963223
# Patient_48   0.073797   0.553854   0.969303    0.523098
# Patient_49   0.045446   0.280963   0.950411    0.890264
# Patient_50   0.583656   0.077735   0.974395    0.986211
#
#             Overall Survival (Months)  Overall Survival Status       PC1  \
# PatientID
# Patient_1                         118                        0  0.665868
# Patient_2                          63                        1  0.511567
# Patient_3                          17                        0 -0.317563
# Patient_4                          73                        1 -0.569133
# Patient_5                          33                        1 -0.198698
# Patient_6                         117                        0  0.019571
# Patient_7                          84                        0  0.275556
# Patient_8                          77                        0 -0.865165
# Patient_9                          92                        0  0.112698
# Patient_10                        112                        1 -0.129053
# Patient_11                         29                        0 -0.273573
# Patient_12                         13                        0  0.037249
# Patient_13                         46                        0  0.010931
# Patient_14                         35                        0 -0.297744
# Patient_15                          6                        0 -0.469197
# Patient_16                         82                        0 -0.560102
# Patient_17                        115                        1  0.128571
# Patient_18                         69                        1 -0.373844
# Patient_19                         47                        0 -0.099727
# Patient_20                         25                        0  0.734096
# Patient_21                         66                        0 -0.764586
# Patient_22                         10                        1  0.361702
# Patient_23                         56                        0 -0.080881
# Patient_24                         30                        1 -0.029331
# Patient_25                        114                        0  0.959401
# Patient_26                        109                        0  0.083397
# Patient_27                          5                        0 -0.142852
# Patient_28                        119                        0  0.348304
# Patient_29                         33                        1 -0.283080
# Patient_30                        118                        1 -0.118577
# Patient_31                         65                        0  0.065551
# Patient_32                         18                        0 -0.855017
# Patient_33                         96                        1 -0.001242
# Patient_34                        111                        1 -0.144587
# Patient_35                         49                        1 -0.254182
# Patient_36                         11                        1  0.739992
# Patient_37                         85                        0 -0.359400
# Patient_38                         26                        1 -0.462642
# Patient_39                         63                        0  0.312585
# Patient_40                         89                        1 -0.059146
# Patient_41                         86                        1  0.249447
# Patient_42                         59                        1  0.573103
# Patient_43                         27                        1 -0.074918
# Patient_44                         49                        1  0.526544
# Patient_45                         77                        0  0.009805
# Patient_46                         33                        0 -0.228175
# Patient_47                         98                        1  0.271506
# Patient_48                        105                        1  0.381733
# Patient_49                         99                        0  0.405598
# Patient_50                          1                        1  0.227638
#
#                  PC2        tX        tY
# PatientID
# Patient_1   0.324440  3.431245  3.062351
# Patient_2   0.289104  4.011163  3.397772
# Patient_3  -0.137527  3.009518  5.819115
# Patient_4  -0.677812  3.416075  6.697261
# Patient_5  -0.359708  3.681051  6.130629
# Patient_6  -0.309206  2.501966  6.266922
# Patient_7   0.324325  2.458168  2.795853
# Patient_8  -0.351273  3.165118  6.711374
# Patient_9   0.451115  2.087924  4.187109
# Patient_10  0.004266  1.691938  5.862638
# Patient_11  0.202849  1.388744  5.915649
# Patient_12 -0.652428  4.398252  5.049097
# Patient_13  0.812839  0.949521  4.469089
# Patient_14  0.304179  1.609426  3.342196
# Patient_15  0.664162  1.263798  4.167125
# Patient_16  0.485299  1.340099  3.579565
# Patient_17 -0.165001  2.904939  5.411062
# Patient_18  0.141085  2.219077  4.578837
# Patient_19 -0.230674  4.651763  4.848184
# Patient_20  0.125877  3.451222  3.213583
# Patient_21  0.279717  2.034171  6.897067
# Patient_22  0.393679  2.597337  3.370745
# Patient_23  0.217675  2.286639  4.307335
# Patient_24 -0.302687  3.102639  5.546954
# Patient_25  0.175978  3.843748  2.658678
# Patient_26  0.181102  4.635354  4.508499
# Patient_27  0.114718  1.308799  5.492499
# Patient_28  0.025579  3.264333  3.802906
# Patient_29  0.661731  1.495047  3.908049
# Patient_30 -0.207033  4.882792  4.906000
# Patient_31 -0.618182  3.944463  5.521094
# Patient_32 -0.447052  3.136582  6.825739
# Patient_33  0.080285  1.696751  5.468112
# Patient_34  0.654281  0.866259  4.507125
# Patient_35 -0.139617  2.872820  5.184756
# Patient_36  0.037148  3.957201  3.306466
# Patient_37  0.371024  1.141070  5.682141
# Patient_38 -0.355941  4.922384  5.720949
# Patient_39 -0.669947  3.822725  4.983679
# Patient_40 -0.227779  3.136181  4.610541
# Patient_41 -0.796097  4.121579  5.752394
# Patient_42 -0.148514  3.419774  3.771935
# Patient_43  0.393249  1.196217  4.816087
# Patient_44  0.102934  4.334974  3.463699
# Patient_45 -0.015652  1.043429  5.846634
# Patient_46  0.013698  2.431528  6.330534
# Patient_47  0.204893  2.383097  2.926329
# Patient_48 -0.679701  4.243531  6.085301
# Patient_49 -0.491823  3.612066  4.607306
# Patient_50 -0.053575  2.726514  4.195039

# %%
# Cluster the data
clustering_survival.cluster_data()
# Out:
# /home/vpp1/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Visualize clusters
clustering_survival.visualize_clusters()

# %%
# Plot Kaplan-Meier curves
clustering_survival.plot_kaplan_meier()

# %%
# Generate summary table
summary_table = clustering_survival.generate_summary_table()

# %%
print(summary_table)
# Out:
#   Total number of patients Alive Deceased Median survival time
# 1                       11     5        6                 98.0
# 4                        7     3        4                 69.0
# 0                        5     4        1                 73.0
# 3                        9     5        4                105.0
# 2                        9     5        4                 89.0
# 5                        9     5        4                111.0

# %%
clustering_survival.perform_log_rank_test()
# Out:
# Log Rank test for survival
# Group 1 vs Group 2 : p_value
#    1   vs   4   :  0.77
#    1   vs   0   :  0.46
#    1   vs   3   :  0.53
#    1   vs   2   :  0.70
#    1   vs   5   :  0.98
#    4   vs   0   :  0.45
#    4   vs   3   :  0.72
#    4   vs   2   :  0.97
#    4   vs   5   :  0.92
#    0   vs   3   :  0.56
#    0   vs   2   :  0.61
#    0   vs   5   :  0.56
#    3   vs   2   :  0.19
#    3   vs   5   :  0.43
#    2   vs   5   :  0.15
# []

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from lifelines.statistics import logrank_test
import matplotlib.pyplot as plt
from yellowbrick.cluster import KElbowVisualizer
import pandas as pd
import seaborn as sns
from lifelines import KaplanMeierFitter
import matplotlib.cm as cm
import itertools
from sklearn.cluster import DBSCAN
import os

class ClusteringSurvival:
    def __init__(self, data_path, save_path='final_result/', clinical_df_path=None):
        self.df = pd.read_csv(data_path).set_index('PatientID')
        self.latent_features = self.df.to_numpy()
        self.pIDs = self.df.index
        self.save_dir = save_path
        os.makedirs(self.save_dir, exist_ok=True)
        self.clnc_df = pd.read_csv(clinical_df_path).set_index('PatientID')
        self.process()

    def process(self):
        if self.clnc_df is not None:
            self.df = self.df.join(self.clnc_df, how='inner') 
        
    def pca_tsne(self):
        pca = PCA(n_components=2)
        X_pca = pca.fit_transform(self.latent_features)
        self.df['PC1'] = X_pca[:, 0]
        self.df['PC2'] = X_pca[:, 1]
        
        tsne = TSNE(n_components=2)
        X_tsne = tsne.fit_transform(self.latent_features)
        self.df['tX'] = X_tsne[:, 0]
        self.df['tY'] = X_tsne[:, 1]

    def find_optimal_clusters(self, min_clusters=2, max_clusters=11):
        model = KMeans(random_state=42)
        visualizer = KElbowVisualizer(model, k=(min_clusters, max_clusters))
        visualizer.fit(self.latent_features)
        visualizer.show()

        fig = visualizer.ax.get_figure()
        # fig.savefig(f'{self.save_dir}kelbow.png', dpi=150)
        fig.savefig(f'{self.save_dir}kelbow.jpeg', format="jpeg", dpi=150)
        
        self.optimal_clusters = visualizer.elbow_value_

    def cluster_data(self):
        if not hasattr(self, 'optimal_clusters'):
            raise ValueError("Please run 'find_optimal_clusters' method before clustering the data.")
        kmeans = KMeans(n_clusters=self.optimal_clusters, random_state=0).fit(self.latent_features)
        self.labels = kmeans.labels_
        self.df['groups'] = self.labels 
        self.generate_color_list_based_on_median_survival()

    def cluster_data2(self, kclust):
        kmeans = KMeans(n_clusters=kclust, random_state=0).fit(self.latent_features)
        self.labels = kmeans.labels_
        self.df['groups'] = self.labels 
        self.generate_color_list_based_on_median_survival()

    def visualize_clusters(self):
        plt.figure(figsize=(20, 8))
        plt.subplot(1, 2, 1)
        sns.scatterplot(data=self.df, x='PC1', y='PC2', hue='groups', palette=self.color_list)

        plt.subplot(1, 2, 2)
        sns.scatterplot(data=self.df, x='tX', y='tY', hue='groups', palette=self.color_list)

    def save_visualize_clusters(self):
        plt.figure(figsize=(10, 8))
        sns.scatterplot(data=self.df, x='PC1', y='PC2', hue='groups', palette=self.color_list)
        plt.savefig(f'{self.save_dir}pca.png', dpi=300)
        plt.savefig(f'{self.save_dir}pca.jpeg', dpi=300)
        plt.close()

        plt.figure(figsize=(10, 8))
        sns.scatterplot(data=self.df, x='tX', y='tY', hue='groups', palette=self.color_list)
        plt.savefig(f'{self.save_dir}tsne.png', dpi=300)
        plt.savefig(f'{self.save_dir}tsne.jpeg', dpi=300)

    def generate_color_list_based_on_median_survival(self):
        groups = self.df['groups'].unique()
        median_survival_times = {group: self.df[self.df['groups'] == group]['Overall Survival (Months)'].median() for group in groups}
        sorted_groups = sorted(groups, key=median_survival_times.get, reverse=True)

        vibgyor_colors = cm.rainbow(np.linspace(0, 1, len(groups)))
        self.color_list = {group: color for group, color in zip(sorted_groups, vibgyor_colors)}

    def perform_log_rank_test(self, alpha=0.05):
        if self.df is None:
            raise ValueError("Please run 'cluster_data' or 'cluster_data2' method before performing log rank test.")
        
        groups = self.df['groups'].unique()
        significant_pairs = []

        print("Log Rank test for survival")
        print("Group 1 vs Group 2 : p_value")

        for pair in itertools.combinations(groups, 2):
            group_a = self.df[self.df['groups'] == pair[0]]
            group_b = self.df[self.df['groups'] == pair[1]]
            results = logrank_test(group_a['Overall Survival (Months)'],
                                   group_b['Overall Survival (Months)'],
                                   group_a['Overall Survival Status'],
                                   group_b['Overall Survival Status'])

            significance_marker = "****" if results.p_value < alpha else ""
            print(f"   {pair[0]}   vs   {pair[1]}   :  {results.p_value:.2f} {significance_marker}")

            if results.p_value < alpha:
                significant_pairs.append(pair)
        self.significant_pairs = significant_pairs
        return self.significant_pairs

    def generate_summary_table(self):
        groups = self.df['groups'].unique()
        summary_table = pd.DataFrame(columns=['Total number of patients', 'Alive', 'Deceased', 'Median survival time'], index=groups)
    
        for group in groups:
            group_data = self.df[self.df['groups'] == group]
            total_patients = len(group_data)
            alive = len(group_data[group_data['Overall Survival Status'] == 0])
            deceased = len(group_data[group_data['Overall Survival Status'] == 1])
    
            kmf = KaplanMeierFitter()
            kmf.fit(group_data['Overall Survival (Months)'], group_data['Overall Survival Status'])
    
            median_survival_time = kmf.median_survival_time_
            summary_table.loc[group] = [total_patients, alive, deceased, median_survival_time]
    
        # Save the summary table as a CSV file
        summary_table_path = os.path.join(self.save_dir, 'survival_summary_table.csv')
        summary_table.to_csv(summary_table_path)
        print(f"Summary table saved to {summary_table_path}")
    
        return summary_table


    def plot_kaplan_meier(self, plot_for_groups=True, name='temp_k5'):
        kmf = KaplanMeierFitter()

        plt.figure(figsize=(8, 6))
        plt.grid(False)
        if plot_for_groups:
            groups = sorted(self.df['groups'].unique())
            for group in groups:
                group_data = self.df[self.df['groups'] == group]
                kmf.fit(group_data['Overall Survival (Months)'], group_data['Overall Survival Status'], label=f'Group {group}')
                kmf.plot(ci_show=False, linewidth=2, color=self.color_list[group])
            plt.title("Kaplan-Meier Curves for Each Group")
        else:
            kmf.fit(self.df['Overall Survival (Months)'], self.df['Overall Survival Status'], label='All Data')
            kmf.plot(ci_show=False, linewidth=2, color='black')
            plt.title("Kaplan-Meier Curve for All Data")

        plt.gca().set_facecolor('#f5f5f5')
        plt.grid(color='lightgrey', linestyle='-', linewidth=0.5)
        plt.xlabel("Overall Survival (Months)", fontweight='bold')
        plt.ylabel("Survival Probability", fontweight='bold')
        plt.legend()
        # plt.savefig(f'{self.save_dir}{name}_kaplan_meier.png', dpi=300)
        plt.savefig(f'{self.save_dir}{name}_kaplan_meier.jpeg', dpi=300)
        plt.show()

    def club_two_groups(self, primary_group, secondary_group):
        self.df.loc[self.df['groups'] == secondary_group, 'groups'] = primary_group
        unique_groups = sorted(self.df['groups'].unique())
        mapping = {old: new for new, old in enumerate(unique_groups)}
        self.df['groups'] = self.df['groups'].map(mapping)

        self.generate_color_list_based_on_median_survival()
        self.summary_table = self.generate_summary_table()

    def plot_median_survival_bar(self, name='temp_k5'):
        summary_df = self.generate_summary_table()
        summary_df['group'] = summary_df.index
        max_val = summary_df["Median survival time"].replace(np.inf, np.nan).max()
        summary_df["Display Median"] = summary_df["Median survival time"].replace(np.inf, max_val * 1.1)

        summary_df = summary_df.sort_index()
        colors = [self.color_list[group] for group in summary_df.index]

        num_groups = len(summary_df)
        plt.figure(figsize=(6, num_groups * 0.8))
        plt.grid(False)
        sns.barplot(data=summary_df, y='group', x="Display Median", palette=colors, orient="h", order=summary_df.index)
        plt.xlabel("Median Survival Time (Months)")
        plt.ylabel("Groups")
        plt.title("Median Survival Time by Group")
        plt.tight_layout()
        
        # plt.savefig(f'{self.save_dir}{name}_median_survival.png', dpi=300)
        plt.savefig(f'{self.save_dir}{name}_median_survival.jpeg', dpi=300)

        plt.show()

# %%
# clustering_survival.py
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from lifelines.statistics import logrank_test
import matplotlib.pyplot as plt
from yellowbrick.cluster import KElbowVisualizer
import pandas as pd
import seaborn as sns
from lifelines import KaplanMeierFitter
import matplotlib.cm as cm
import itertools
from sklearn.cluster import DBSCAN
import os

class ClusteringSurvival:
    def __init__(self, data_path, clinical_df_path, save_path='final_result/'):
        self.df = pd.read_csv(data_path).set_index('PatientID')
        self.latent_features = self.df.to_numpy()
        self.pIDs = self.df.index
        self.save_dir = save_path
        os.makedirs(self.save_dir, exist_ok=True)
        self.clnc_df = pd.read_csv(clinical_df_path).set_index('PatientID')
        self.process()

        # Perform the main processing pipeline automatically
        self.pca_tsne()
        self.find_optimal_clusters()
        self.cluster_data()
        self.visualize_clusters()
        self.plot_kaplan_meier()
        self.summary_table = self.generate_summary_table()
        self.perform_log_rank_test()
        

    def process(self):
        if self.clnc_df is not None:
            self.df = self.df.join(self.clnc_df, how='inner') 
        
    def pca_tsne(self):
        pca = PCA(n_components=2)
        X_pca = pca.fit_transform(self.latent_features)
        self.df['PC1'] = X_pca[:, 0]
        self.df['PC2'] = X_pca[:, 1]
        
        tsne = TSNE(n_components=2)
        X_tsne = tsne.fit_transform(self.latent_features)
        self.df['tX'] = X_tsne[:, 0]
        self.df['tY'] = X_tsne[:, 1]

    def find_optimal_clusters(self, min_clusters=2, max_clusters=11):
        model = KMeans(random_state=42)
        visualizer = KElbowVisualizer(model, k=(min_clusters, max_clusters))
        visualizer.fit(self.latent_features)
        visualizer.show()

        fig = visualizer.ax.get_figure()
        # fig.savefig(f'{self.save_dir}kelbow.png', dpi=150)
        fig.savefig(f'{self.save_dir}kelbow.jpeg', format="jpeg", dpi=150)
        
        self.optimal_clusters = visualizer.elbow_value_

    def cluster_data(self):
        if not hasattr(self, 'optimal_clusters'):
            raise ValueError("Please run 'find_optimal_clusters' method before clustering the data.")
        kmeans = KMeans(n_clusters=self.optimal_clusters, random_state=0).fit(self.latent_features)
        self.labels = kmeans.labels_
        self.df['groups'] = self.labels 
        self.generate_color_list_based_on_median_survival()

    def cluster_data2(self, kclust):
        kmeans = KMeans(n_clusters=kclust, random_state=0).fit(self.latent_features)
        self.labels = kmeans.labels_
        self.df['groups'] = self.labels 
        self.generate_color_list_based_on_median_survival()


    def visualize_clusters(self):
        plt.figure(figsize=(10, 8))
        sns.scatterplot(data=self.df, x='PC1', y='PC2', hue='groups', palette=self.color_list)
        plt.savefig(f'{self.save_dir}pca.png', dpi=300)
        plt.savefig(f'{self.save_dir}pca.jpeg', dpi=300)
        plt.close()

        plt.figure(figsize=(10, 8))
        sns.scatterplot(data=self.df, x='tX', y='tY', hue='groups', palette=self.color_list)
        plt.savefig(f'{self.save_dir}tsne.png', dpi=300)
        plt.savefig(f'{self.save_dir}tsne.jpeg', dpi=300)

    def plot_kaplan_meier(self, plot_for_groups=True, name='kaplan_meier'):
        kmf = KaplanMeierFitter()

        plt.figure(figsize=(8, 6))
        if plot_for_groups:
            groups = sorted(self.df['groups'].unique())
            for group in groups:
                group_data = self.df[self.df['groups'] == group]
                kmf.fit(group_data['Overall Survival (Months)'], group_data['Overall Survival Status'], label=f'Group {group}')
                kmf.plot(ci_show=False, linewidth=2, color=self.color_list[group])
        else:
            kmf.fit(self.df['Overall Survival (Months)'], self.df['Overall Survival Status'], label='All Data')
            kmf.plot(ci_show=False, linewidth=2, color='black')

        plt.savefig(f'{self.save_dir}{name}.jpeg', dpi=300)
        plt.show()

    def generate_color_list_based_on_median_survival(self):
        groups = self.df['groups'].unique()
        median_survival_times = {group: self.df[self.df['groups'] == group]['Overall Survival (Months)'].median() for group in groups}
        sorted_groups = sorted(groups, key=median_survival_times.get, reverse=True)

        vibgyor_colors = cm.rainbow(np.linspace(0, 1, len(groups)))
        self.color_list = {group: color for group, color in zip(sorted_groups, vibgyor_colors)}

    def perform_log_rank_test(self, alpha=0.05):
        if self.df is None:
            raise ValueError("Please run 'cluster_data' or 'cluster_data2' method before performing log rank test.")
        
        groups = self.df['groups'].unique()
        significant_pairs = []
        log_rank_results = []
    
        print("Log Rank test for survival")
        print("Group 1 vs Group 2 : p_value")
    
        for pair in itertools.combinations(groups, 2):
            group_a = self.df[self.df['groups'] == pair[0]]
            group_b = self.df[self.df['groups'] == pair[1]]
            results = logrank_test(group_a['Overall Survival (Months)'],
                                   group_b['Overall Survival (Months)'],
                                   group_a['Overall Survival Status'],
                                   group_b['Overall Survival Status'])
    
            significance_marker = "****" if results.p_value < alpha else ""
            result_string = f"{pair[0]} vs {pair[1]} :  {results.p_value:.2f} {significance_marker}"
            log_rank_results.append(result_string)
            print(result_string)
    
            if results.p_value < alpha:
                significant_pairs.append(pair)
    
        # Save the log-rank results to a file
        log_rank_path = os.path.join(self.save_dir, 'log_rank_test_results.txt')
        with open(log_rank_path, 'w') as f:
            f.write("Log Rank Test Results for Survival\n")
            for result in log_rank_results:
                f.write(result + "\n")
        print(f"Log-rank test results saved to {log_rank_path}")
    
        if significant_pairs:
            significant_path = os.path.join(self.save_dir, 'significant_pairs.txt')
            with open(significant_path, 'w') as f:
                f.write("Significant Group Pairs (p < 0.05):\n")
                for pair in significant_pairs:
                    f.write(f"{pair[0]} vs {pair[1]}\n")
            print(f"Significant pairs saved to {significant_path}")
    
        self.significant_pairs = significant_pairs
        return self.significant_pairs


    def generate_summary_table(self):
        groups = self.df['groups'].unique()
        summary_table = pd.DataFrame(columns=['Total number of patients', 'Alive', 'Deceased', 'Median survival time'], index=groups)
    
        for group in groups:
            group_data = self.df[self.df['groups'] == group]
            total_patients = len(group_data)
            alive = len(group_data[group_data['Overall Survival Status'] == 0])
            deceased = len(group_data[group_data['Overall Survival Status'] == 1])
    
            kmf = KaplanMeierFitter()
            kmf.fit(group_data['Overall Survival (Months)'], group_data['Overall Survival Status'])
    
            median_survival_time = kmf.median_survival_time_
            summary_table.loc[group] = [total_patients, alive, deceased, median_survival_time]
    
        # Save the summary table as a CSV file
        summary_table_path = os.path.join(self.save_dir, 'summary_table.csv')
        summary_table.to_csv(summary_table_path)
        print(f"Summary table saved to {summary_table_path}")
    
        return summary_table

    def plot_kaplan_meier(self, plot_for_groups=True, name='temp_k5'):
        kmf = KaplanMeierFitter()

        plt.figure(figsize=(8, 6))
        plt.grid(False)
        if plot_for_groups:
            groups = sorted(self.df['groups'].unique())
            for group in groups:
                group_data = self.df[self.df['groups'] == group]
                kmf.fit(group_data['Overall Survival (Months)'], group_data['Overall Survival Status'], label=f'Group {group}')
                kmf.plot(ci_show=False, linewidth=2, color=self.color_list[group])
            plt.title("Kaplan-Meier Curves for Each Group")
        else:
            kmf.fit(self.df['Overall Survival (Months)'], self.df['Overall Survival Status'], label='All Data')
            kmf.plot(ci_show=False, linewidth=2, color='black')
            plt.title("Kaplan-Meier Curve for All Data")

        plt.gca().set_facecolor('#f5f5f5')
        plt.grid(color='lightgrey', linestyle='-', linewidth=0.5)
        plt.xlabel("Overall Survival (Months)", fontweight='bold')
        plt.ylabel("Survival Probability", fontweight='bold')
        plt.legend()
        # plt.savefig(f'{self.save_dir}{name}_kaplan_meier.png', dpi=300)
        plt.savefig(f'{self.save_dir}{name}_kaplan_meier.jpeg', dpi=300)
        plt.show()

    def club_two_groups(self, primary_group, secondary_group):
        self.df.loc[self.df['groups'] == secondary_group, 'groups'] = primary_group
        unique_groups = sorted(self.df['groups'].unique())
        mapping = {old: new for new, old in enumerate(unique_groups)}
        self.df['groups'] = self.df['groups'].map(mapping)

        self.generate_color_list_based_on_median_survival()
        self.summary_table = self.generate_summary_table()

    def plot_median_survival_bar(self, name='temp_k5'):
        summary_df = self.generate_summary_table()
        summary_df['group'] = summary_df.index
        max_val = summary_df["Median survival time"].replace(np.inf, np.nan).max()
        summary_df["Display Median"] = summary_df["Median survival time"].replace(np.inf, max_val * 1.1)

        summary_df = summary_df.sort_index()
        colors = [self.color_list[group] for group in summary_df.index]

        num_groups = len(summary_df)
        plt.figure(figsize=(6, num_groups * 0.8))
        plt.grid(False)
        sns.barplot(data=summary_df, y='group', x="Display Median", palette=colors, orient="h", order=summary_df.index)
        plt.xlabel("Median Survival Time (Months)")
        plt.ylabel("Groups")
        plt.title("Median Survival Time by Group")
        plt.tight_layout()
        
        # plt.savefig(f'{self.save_dir}{name}_median_survival.png', dpi=300)
        plt.savefig(f'{self.save_dir}{name}_median_survival.jpeg', dpi=300)

        plt.show()
